# %%
import pandas as pd
import numpy as np

# %%
critics_df = pd.read_json("../output/critics.json")
critics_df.head()
# Out:
#                                    album description  \
# 0  Direct, honest and powerful, Patch The Sky can...
# 1  It's not Puff's best collection by any stretch...
# 2  Save a few moments of "over-rapping," his pen ...
# 3  Free TC moves way less outside contribution th...
# 4  T5DOA is a fine body of work, but falls short ...
#
#                                  album id                 album name  \
# 0          /music/patch-the-sky/bob-mould              Patch the Sky
# 1           /music/mmm-mixtape/puff-daddy              MMM [Mixtape]
# 2  /music/the-incredible-true-story/logic  The Incredible True Story
# 3             /music/free-tc/ty-dolla-ign                    Free TC
# 4     /music/top-5-dead-or-alive/jadakiss        Top 5 Dead or Alive
#
#    album rating publication name
# 0            80       The Source
# 1            60       The Source
# 2            80       The Source
# 3            60       The Source
# 4            70       The Source

# %%
critics_df.describe()
# Out:
#         album rating
# count  187304.000000
# mean       70.914337
# std        14.123420
# min         0.000000
# 25%        60.000000
# 50%        70.000000
# 75%        80.000000
# max       100.000000

# %%
import plotly
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

plotly.offline.init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
data1 = go.Histogram(x = critics_df['album rating'],)
layout1 = go.Layout(
    title= 'Histogram of Album Scores',
    #hovermode= 'closest',
    xaxis = dict(
        title= 'Score',
    ),
    yaxis = dict(
        title = 'Number of Reviews'
    )
)

fig1 = dict(data=[data1], layout=layout1)
iplot(fig1, filename='basic histogram')
# Out:
# <div id="31ba5042-f065-430c-8d07-a0ff011c452b" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("31ba5042-f065-430c-8d07-a0ff011c452b", [{"type": "histogram", "x": [80, 60, 80, 60, 70, 70, 80, 90, 80, 70, 80, 80, 60, 70, 80, 90, 90, 70, 80, 80, 70, 60, 70, 80, 50, 80, 90, 80, 70, 90, 70, 90, 80, 90, 60, 80, 100, 90, 80, 90, 80, 80, 80, 70, 80, 60, 40, 70, 80, 80, 70, 90, 80, 40, 90, 80, 80, 90, 80, 70, 83, 50, 75, 83, 67, 83, 75, 75, 91, 67, 83, 50, 91, 83, 50, 67, 75, 83, 83, 50, 75, 91, 58, 75, 33, 83, 75, 42, 91, 83, 83, 91, 91, 100, 91, 83, 83, 100, 91, 91, 83, 83, 83, 91, 83, 91, 91, 91, 100, 100, 100, 91, 91, 83, 83, 100, 91, 83, 91, 100, 80, 70, 90, 50, 70, 70, 70, 50, 80, 60, 80, 80, 70, 60, 80, 60, 70, 70, 70, 80, 80, 60, 50, 60, 70, 60, 80, 50, 80, 40, 80, 80, 80, 100, 60, 80, 80, 60, 60, 80, 80, 80, 60, 80, 100, 80, 60, 60, 60, 100, 80, 60, 60, 80, 80, 80, 80, 80, 80, 80, 80, 60, 70, 70, 80, 90, 80, 90, 80, 70, 90, 70, 80, 80, 80, 90, 80, 80, 80, 70, 80, 80, 60, 80, 50, 80, 80, 80, 80, 80, 75, 50, 88, 88, 63, 88, 88, 75, 88, 63, 63, 88, 63, 75, 88, 75, 75, 63, 88, 75, 75, 75, 75, 88, 63, 63, 75, 50, 75, 50, 70, 60, 70, 70, 70, 50, 80, 70, 80, 70, 80, 50, 70, 80, 80, 60, 70, 90, 90, 80, 80, 70, 80, 70, 80, 80, 40, 40, 90, 80, 80, 80, 80, 70, 70, 70, 70, 70, 80, 80, 80, 80, 70, 80, 80, 70, 80, 80, 70, 70, 80, 80, 80, 70, 80, 80, 80, 90, 70, 70, 80, 90, 75, 80, 75, 80, 70, 35, 75, 75, 75, 80, 75, 70, 80, 80, 60, 60, 70, 50, 75, 60, 70, 70, 85, 75, 75, 80, 75, 75, 60, 80, 80, 80, 40, 70, 60, 70, 80, 80, 60, 80, 80, 90, 70, 80, 90, 60, 80, 80, 70, 60, 90, 70, 70, 80, 60, 70, 70, 60, 90, 70, 80, 90, 60, 80, 80, 70, 80, 80, 90, 80, 40, 90, 80, 80, 80, 80, 70, 80, 70, 80, 70, 70, 80, 80, 80, 40, 80, 30, 33, 58, 70, 70, 83, 100, 83, 83, 75, 75, 80, 60, 80, 70, 80, 80, 75, 75, 75, 67, 67, 91, 83, 80, 80, 80, 80, 70, 50, 75, 50, 75, 91, 75, 67, 80, 80, 70, 80, 80, 80, 100, 42, 75, 91, 83, 80, 60, 80, 80, 80, 80, 83, 75, 75, 83, 80, 80, 80, 80, 75, 83, 58, 75, 83, 75, 58, 50, 100, 75, 50, 58, 75, 67, 50, 83, 75, 58, 42, 67, 75, 67, 100, 67, 67, 67, 50, 42, 75, 67, 91, 100, 91, 91, 91, 91, 83, 83, 91, 83, 91, 91, 83, 91, 83, 91, 91, 83, 91, 91, 83, 91, 91, 91, 91, 91, 91, 91, 100, 91, 67, 74, 84, 75, 78, 90, 78, 77, 85, 53, 67, 75, 86, 86, 80, 52, 86, 81, 69, 61, 88, 78, 72, 85, 75, 78, 69, 68, 88, 75, 80, 80, 80, 70, 80, 70, 80, 70, 60, 80, 60, 90, 80, 90, 80, 80, 70, 80, 80, 80, 70, 70, 80, 80, 80, 80, 80, 80, 90, 100, 70, 80, 80, 80, 70, 70, 80, 80, 80, 80, 80, 80, 80, 70, 80, 80, 80, 80, 80, 50, 80, 80, 80, 70, 80, 80, 70, 80, 80, 80, 80, 70, 50, 80, 70, 80, 80, 60, 80, 70, 80, 60, 80, 80, 70, 70, 90, 60, 80, 50, 80, 70, 60, 80, 80, 70, 60, 80, 80, 80, 70, 75, 37, 88, 88, 75, 88, 63, 75, 88, 75, 75, 63, 88, 37, 88, 0, 100, 37, 63, 63, 88, 75, 75, 75, 75, 75, 75, 63, 50, 88, 15, 60, 55, 80, 60, 85, 85, 80, 80, 80, 85, 70, 90, 85, 65, 75, 80, 75, 80, 65, 70, 80, 80, 70, 70, 80, 80, 80, 70, 80, 85, 95, 75, 85, 80, 90, 70, 80, 80, 70, 40, 90, 70, 75, 60, 80, 80, 80, 70, 80, 80, 70, 80, 60, 90, 80, 80, 80, 70, 30, 40, 50, 80, 80, 80, 50, 70, 70, 90, 80, 80, 70, 80, 80, 70, 70, 90, 70, 80, 60, 70, 60, 20, 70, 80, 80, 90, 70, 60, 60, 70, 80, 80, 80, 80, 80, 70, 80, 80, 80, 80, 60, 60, 50, 80, 80, 80, 70, 70, 80, 80, 80, 60, 80, 60, 70, 60, 80, 69, 70, 70, 67, 78, 69, 72, 75, 68, 63, 79, 41, 72, 80, 72, 38, 76, 77, 70, 74, 66, 64, 80, 66, 68, 80, 74, 80, 55, 81, 60, 60, 40, 60, 40, 40, 60, 80, 40, 60, 60, 60, 60, 100, 60, 60, 80, 80, 80, 80, 80, 60, 60, 60, 80, 60, 60, 100, 60, 20, 75, 42, 50, 67, 91, 83, 100, 67, 100, 67, 75, 67, 100, 67, 67, 50, 91, 67, 83, 75, 100, 75, 50, 83, 67, 75, 50, 67, 83, 67, 80, 80, 70, 70, 80, 90, 80, 90, 50, 90, 80, 80, 70, 70, 90, 90, 80, 40, 70, 90, 90, 80, 80, 70, 90, 80, 70, 50, 80, 80, 80, 80, 70, 80, 80, 80, 70,  ...

# %%
grouped = critics_df.groupby('publication name')
num_ratings = grouped['album rating'].count()
avg_ratings = grouped['album rating'].mean()

grouped_df = pd.DataFrame()
grouped_df['num_ratings'] = num_ratings
grouped_df['avg_ratings'] = avg_ratings
groups = list(grouped.groups)

# %%
data2 = go.Histogram(x=grouped_df['num_ratings'])
layout2 = go.Layout(
    title= 'Number of Reviews Per Publication',
    hovermode= 'closest',
    xaxis = dict(
        title= 'Number of Reviews',
    ),
    yaxis = dict(
        title = 'Number of Publications'
    )
)

fig2 = dict(data=[data2], layout=layout2)
iplot(fig2, filename='basic histogram')
# Out:
# <div id="7679865f-ce39-459d-afa7-fbf1ec04ceb5" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("7679865f-ce39-459d-afa7-fbf1ec04ceb5", [{"type": "histogram", "x": [803, 12696, 410, 3058, 5, 468, 1111, 49, 1814, 1806, 150, 841, 1720, 808, 1853, 1324, 2024, 421, 723, 59, 493, 2009, 822, 49, 3425, 156, 68, 1765, 155, 1371, 1507, 121, 4519, 2425, 787, 3361, 3, 2940, 230, 444, 1795, 62, 101, 517, 542, 492, 67, 85, 403, 1078, 70, 354, 88, 1462, 627, 178, 75, 2281, 25, 110, 424, 6778, 2706, 474, 4405, 135, 158, 2132, 140, 578, 148, 24, 2956, 8720, 34, 822, 9109, 2120, 711, 12, 368, 7334, 700, 1548, 719, 33, 9, 235, 491, 4784, 52, 41, 490, 13, 2496, 286, 3955, 99, 792, 1573, 1452, 1087, 4225, 1086, 368, 4427, 1429, 787, 2244, 1819, 1637, 1412, 512, 61, 673, 1589, 2716, 168, 7932, 4450, 1119, 290, 759, 223, 232, 366, 341, 1752, 4339]}], {"title": "Number of Reviews Per Publication", "hovermode": "closest", "xaxis": {"title": "Number of Reviews"}, "yaxis": {"title": "Number of Publications"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
data3 = go.Box(
    y=grouped_df['num_ratings'],
    name='Number of Reviews',
    boxmean=True,
    jitter = 0.3,
    boxpoints = 'outliers',
)

layout3 = go.Layout(
    title= 'Number of Reviews Per Publication',
    hovermode= 'closest',
    yaxis = dict(
        title = 'Number of Reviews'
    )
)
fig3 = dict(data=[data3])
iplot(fig3, filename='basic histogram')

q75, q25 = np.percentile(grouped_df['num_ratings'], [75 ,25])
iqr = q75 - q25
upper_fence = 1.5*iqr + q75
# Out:
# <div id="ff594890-6f72-47be-9666-036e1437a0bb" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("ff594890-6f72-47be-9666-036e1437a0bb", [{"type": "box", "y": [803, 12696, 410, 3058, 5, 468, 1111, 49, 1814, 1806, 150, 841, 1720, 808, 1853, 1324, 2024, 421, 723, 59, 493, 2009, 822, 49, 3425, 156, 68, 1765, 155, 1371, 1507, 121, 4519, 2425, 787, 3361, 3, 2940, 230, 444, 1795, 62, 101, 517, 542, 492, 67, 85, 403, 1078, 70, 354, 88, 1462, 627, 178, 75, 2281, 25, 110, 424, 6778, 2706, 474, 4405, 135, 158, 2132, 140, 578, 148, 24, 2956, 8720, 34, 822, 9109, 2120, 711, 12, 368, 7334, 700, 1548, 719, 33, 9, 235, 491, 4784, 52, 41, 490, 13, 2496, 286, 3955, 99, 792, 1573, 1452, 1087, 4225, 1086, 368, 4427, 1429, 787, 2244, 1819, 1637, 1412, 512, 61, 673, 1589, 2716, 168, 7932, 4450, 1119, 290, 759, 223, 232, 366, 341, 1752, 4339], "name": "Number of Reviews", "boxmean": true, "jitter": 0.3, "boxpoints": "outliers"}], {}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
num_ratings_truncated = grouped_df[grouped_df['num_ratings'] <= upper_fence]

data2_1 = go.Histogram(x=num_ratings_truncated['num_ratings'])
layout2_1 = go.Layout(
    title= 'Number of Reviews Per Publication (Outliers Omitted, n < ' + str(upper_fence) + ')',
    hovermode= 'closest',
    xaxis = dict(
        title= 'Number of Reviews',
    ),
    yaxis = dict(
        title = 'Number of Publications'
    )
)

fig2_1 = dict(data=[data2_1], layout=layout2_1)
iplot(fig2_1, filename='basic histogram')
# Out:
# <div id="531daa48-90ec-45ce-bc8f-2af825df1f97" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("531daa48-90ec-45ce-bc8f-2af825df1f97", [{"type": "histogram", "x": [803, 410, 3058, 5, 468, 1111, 49, 1814, 1806, 150, 841, 1720, 808, 1853, 1324, 2024, 421, 723, 59, 493, 2009, 822, 49, 3425, 156, 68, 1765, 155, 1371, 1507, 121, 2425, 787, 3361, 3, 2940, 230, 444, 1795, 62, 101, 517, 542, 492, 67, 85, 403, 1078, 70, 354, 88, 1462, 627, 178, 75, 2281, 25, 110, 424, 2706, 474, 135, 158, 2132, 140, 578, 148, 24, 2956, 34, 822, 2120, 711, 12, 368, 700, 1548, 719, 33, 9, 235, 491, 52, 41, 490, 13, 2496, 286, 3955, 99, 792, 1573, 1452, 1087, 4225, 1086, 368, 1429, 787, 2244, 1819, 1637, 1412, 512, 61, 673, 1589, 2716, 168, 1119, 290, 759, 223, 232, 366, 341, 1752]}], {"title": "Number of Reviews Per Publication (Outliers Omitted, n < 4278.0)", "hovermode": "closest", "xaxis": {"title": "Number of Reviews"}, "yaxis": {"title": "Number of Publications"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
data3 = go.Scatter(
    x = grouped_df['num_ratings'],
    y = grouped_df['avg_ratings'].round(1),
    text = groups,
    name = 'Above',
    mode = 'markers',
    marker = dict(
        size = 5,
        color = 'rgba(152, 0, 0, .8)',
        line = dict(
            width = 2,
            color = 'rgb(0, 0, 0)'
        )
    )
)

layout3= go.Layout(
    title= 'Average Rating vs. Number of Reviews By Publication',
    hovermode= 'closest',
    xaxis= dict(
        title= 'Number of Reviews',
        #type = 'log',
        zeroline= False,
        gridwidth= 2,
    ),
    yaxis=dict(
        title= 'Average Rating (100 max)',
        gridwidth= 2,
    ),
    showlegend= False
)

fig3 = dict(data=[data3], layout=layout3)
iplot(fig3, filename='styled-scatter')
# Out:
# <div id="b2206865-6523-4aa4-9e46-53227c57e214" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("b2206865-6523-4aa4-9e46-53227c57e214", [{"type": "scatter", "x": [803, 12696, 410, 3058, 5, 468, 1111, 49, 1814, 1806, 150, 841, 1720, 808, 1853, 1324, 2024, 421, 723, 59, 493, 2009, 822, 49, 3425, 156, 68, 1765, 155, 1371, 1507, 121, 4519, 2425, 787, 3361, 3, 2940, 230, 444, 1795, 62, 101, 517, 542, 492, 67, 85, 403, 1078, 70, 354, 88, 1462, 627, 178, 75, 2281, 25, 110, 424, 6778, 2706, 474, 4405, 135, 158, 2132, 140, 578, 148, 24, 2956, 8720, 34, 822, 9109, 2120, 711, 12, 368, 7334, 700, 1548, 719, 33, 9, 235, 491, 4784, 52, 41, 490, 13, 2496, 286, 3955, 99, 792, 1573, 1452, 1087, 4225, 1086, 368, 4427, 1429, 787, 2244, 1819, 1637, 1412, 512, 61, 673, 1589, 2716, 168, 7932, 4450, 1119, 290, 759, 223, 232, 366, 341, 1752, 4339], "y": [81.3, 73.6, 72.1, 73.3, 86.0, 76.3, 72.1, 70.2, 68.8, 73.9, 73.6, 74.6, 73.9, 76.3, 65.0, 72.7, 72.1, 70.6, 74.2, 73.4, 72.1, 72.0, 72.3, 67.8, 67.2, 79.5, 69.1, 70.5, 75.1, 76.6, 69.1, 62.9, 70.7, 71.5, 74.8, 77.7, 72.3, 74.3, 90.5, 70.5, 75.5, 70.5, 67.9, 70.7, 72.3, 66.8, 68.1, 82.7, 71.8, 73.9, 71.3, 72.7, 74.2, 72.3, 77.1, 86.3, 73.1, 72.7, 78.8, 72.4, 78.4, 71.0, 65.7, 72.4, 68.9, 66.1, 64.6, 69.7, 73.6, 73.4, 85.0, 76.7, 75.2, 69.2, 78.2, 69.7, 67.8, 69.8, 73.2, 72.5, 75.0, 66.1, 73.2, 72.2, 73.5, 77.6, 67.8, 72.6, 75.3, 65.6, 71.5, 60.0, 73.6, 66.9, 64.3, 70.5, 69.8, 70.1, 74.7, 70.1, 68.8, 74.4, 74.2, 74.0, 70.9, 68.8, 67.2, 70.7, 75.7, 70.0, 65.8, 74.4, 71.7, 73.8, 75.7, 72.0, 67.9, 70.0, 70.4, 66.5, 73.1, 67.8, 67.6, 82.1, 72.7, 75.6, 73.5, 71.1, 72.4], "text": ["Absolute Punk (Staff reviews)", "AllMusic", "Almost Cool", "Alternative Press", "Alternative Press (Record Of The Week)", "Amazon.com", "American Songwriter", "Armchair DJ", "Austin Chronicle", "BBC Music", "BBC collective", "Beats Per Minute (formerly One Thirty BPM)", "Billboard", "Billboard.com", "Blender", "Blurt Magazine", "Boston Globe", "CDNow", "CMJ", "Checkout.com", "Chicago Tribune", "Clash Music", "Classic Rock Magazine", "Complex", "Consequence of Sound", "Country Weekly", "CultureDose.net", "DIY Magazine", "DJ Booth", "Delusions of Adequacy", "Dot Music", "Drawer B", "Drowned In Sound", "Dusted Magazine", "E! Online", "Entertainment Weekly", "Epilogue Music", "Exclaim", "Expert Witness (MSN Music)", "Fact Magazine (UK)", "Filter", "Flak Magazine", "HOB.com", "Hartford Courant", "HipHopDX", "Hot Press", "Ink 19", "Ink Blot Magazine", "Junkmedia", "Kerrang!", "L.A. Weekly", "Launch.com", "Logo", "Los Angeles Times", "Lost At Sea", "MSN Consumer Guide (Robert Christgau)", "MTV.com", "Magnet", "Metal Hammer (UK)", "Mixer", "Mixmag", "Mojo", "NOW Magazine", "Neumu.net", "New Musical Express (NME)", "New York Daily News (Jim Faber)", "New York Magazine (Vulture)", "No Ripcord", "Nude As The News", "Observer Music Monthly", "Okayplayer", "Outburn", "Paste Magazine", "Pitchfork", "Planet", "Playlouder", "PopMatters", "Prefix Magazine", "Pretty Much Amazing", "Puncture", "Punknews.org (Staff)", "Q Magazine", "RapReviews.com", "Record Collector", "Resident Advisor", "Resonance", "Revolution", "Revolver", "Rock Sound", "Rolling Stone", "Salon.com", "Select", "ShakingThrough.net", "Shredding Paper", "Slant Magazine", "Sonicnet", "Spin", "Spin Cycle", "Splendid", "Sputnikmusic", "Stylus Magazine", "The 405", "The A.V. Club", "The Boston Phoenix", "The Fly (UK)", "The Guardian", "The Independent (UK)", "The Independent on Sunday (UK)", "The Line of Best Fit", "The New York Times", "The Observer (UK)", "The Quietus", "The Skinny", "The Source", "The Telegraph (UK)", "The Wire", "Tiny Mix Tapes", "Trouser Press", "Uncut", "Under The Radar", "Urb", "Vibe", "Village Voice", "Village Voice (Consumer Guide)", "Wall of Sound", "XLR8r", "XXL", "cokemachine ...
