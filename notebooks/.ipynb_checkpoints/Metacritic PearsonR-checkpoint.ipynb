# %%
import pandas as pd
import numpy as np

# %%
import psycopg2
# Out:
# /Users/michael/anaconda3/lib/python3.6/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %%
try:
    conn = psycopg2.connect("dbname=metacritic user=postgres")
except:
    print("cannot connect")

# %%
cur = conn.cursor()

# %%
import pandas.io.sql as sqlio

# %%
sql = "select * from critics;"
critics = sqlio.read_sql_query(sql, conn)

# %%
critics.head()
# Out:
#                                      id           name
# 0  a189f8ea-e791-4c81-bd22-490cdf4591b1           Logo
# 1  d5f89497-55c5-4c5c-9272-be319f04b087  The A.V. Club
# 2  f5ce11dc-eddd-415f-9e12-bb085014c5f6        Exclaim
# 3  cd9d6f62-d07b-49e8-af6a-0db0773672de        The 405
# 4  72cdb8d5-cf1e-4ada-8111-f42ddd3e6167       Kerrang!

# %%
sql = "select * from albums;"
albums = sqlio.read_sql_query(sql, conn)
#conn = None

# %%
albums.head()
# Out:
#                                      id               name artist  \
# 0  1463a7e4-5bad-482a-9f85-9ac53fce479f               2:54   2:54
# 1  b3148743-3cc2-41ab-b6c9-67516c0b08eb       The  Other I   2:54
# 2  0ae002f0-f35c-43d2-ae14-123dcb1b62fa        Plays Music   33.3
# 3  844ffd1e-c437-436f-8547-a57016da09d0       The Hard Way    213
# 4  5cd77908-b875-4e9f-aa41-100c08627f08  Don't Tread On Me    311
#
#                                            genres  \
# 0  [Pop/Rock, Alternative/Indie Rock, Indie Rock]
# 1   [Pop/Rock, Alternative/Indie Rock, Hard Rock]
# 2                     [Indie, Rock, Instrumental]
# 3                                           [Rap]
# 4                             [Rock, Alternative]
#
#                           link  \
# 0               /music/254/254
# 1       /music/the-other-i/254
# 2       /music/plays-music/333
# 3      /music/the-hard-way/213
# 4  /music/dont-tread-on-me/311
#
#                                             img_link  mc_rating  usr_rating
# 0  http://static.metacritic.com/images/products/m...       68.0         8.3
# 1  http://static.metacritic.com/images/products/m...       69.0         NaN
# 2  http://static.metacritic.com/images/products/m...       51.0         NaN
# 3  http://static.metacritic.com/images/products/m...       56.0         8.0
# 4  http://static.metacritic.com/images/products/m...       51.0         6.1

# %%
sql = """select ratings.album_name, albums.artist, albums.mc_rating, ratings.critic_id, ratings.album_id from ratings 
JOIN albums ON albums.id = ratings.album_id;"""
ratings = sqlio.read_sql_query(sql, conn)

# %%
ratings.head()
# Out:
#            album_name           artist  mc_rating  \
# 0  The Monsanto Years       Neil Young       61.0
# 1               Venus     Joy Williams       66.0
# 2            Teen Men         Teen Men       71.0
# 3              Payola    Desaparecidos       76.0
# 4    Pageant Material  Kacey Musgraves       79.0
#
#                               critic_id                              album_id
# 0  6e890ea9-d4b9-4976-9d6b-03163632a4be  e26e2612-065a-4437-a4ca-d76e0d093828
# 1  6e890ea9-d4b9-4976-9d6b-03163632a4be  8b699df4-5f35-44aa-b851-591e0415a8df
# 2  6e890ea9-d4b9-4976-9d6b-03163632a4be  c02f8427-58ca-4509-b8c8-26353c04e96d
# 3  6e890ea9-d4b9-4976-9d6b-03163632a4be  b1a93cdf-e97c-4e9d-a919-a04db27d00c7
# 4  6e890ea9-d4b9-4976-9d6b-03163632a4be  089f2f33-c38c-42fe-9c2e-9e4f2c574ee4

# %%
rating_totals = pd.DataFrame(ratings.groupby('album_id')['mc_rating'].count())
rating_totals.columns = ['rating_count']
rating_totals['mc_rating'] = ratings.groupby('album_id')['mc_rating'].max()
rating_totals['album_name'] = ratings.groupby('album_id')['album_name'].max()
rating_totals['artist'] = ratings.groupby('album_id')['artist'].max()
rating_totals.head()
# Out:
#                                       rating_count  album_rating  \
# album_id
# 000170c8-cc89-418f-85d6-99b2cddbfe2a             6          73.0
# 00023c63-5cf0-496b-9fed-aedd51e258bd            11          75.0
# 0002e56a-0c28-4e7d-a417-70ba6069674b             6          72.0
# 000cbff7-17f1-4dd8-9cd9-5eb1157fbb95            20          61.0
# 0013b996-5b63-4dd3-aeea-d6a05b9f27ed             6          85.0
#
#                                                                  mc_rating  \
# album_id
# 000170c8-cc89-418f-85d6-99b2cddbfe2a  Ten Songs from Live at Carnegie Hall
# 00023c63-5cf0-496b-9fed-aedd51e258bd                          New Favorite
# 0002e56a-0c28-4e7d-a417-70ba6069674b                        Thunder Thighs
# 000cbff7-17f1-4dd8-9cd9-5eb1157fbb95                        T.I. Vs T.I.P.
# 0013b996-5b63-4dd3-aeea-d6a05b9f27ed                             Traveller
#
#                                                              artist
# album_id
# 000170c8-cc89-418f-85d6-99b2cddbfe2a                     Ryan Adams
# 00023c63-5cf0-496b-9fed-aedd51e258bd  Alison Krauss & Union Station
# 0002e56a-0c28-4e7d-a417-70ba6069674b                   Kimya Dawson
# 000cbff7-17f1-4dd8-9cd9-5eb1157fbb95                           T.I.
# 0013b996-5b63-4dd3-aeea-d6a05b9f27ed                Chris Stapleton

# %%
crosstab = pd.pivot_table(data=ratings, values='album_rating', index='critic_id', columns='album_id')

# %%
crosstab.head()
# Out:
# album_id                              000170c8-cc89-418f-85d6-99b2cddbfe2a  \
# critic_id
# 06193874-b01f-4bde-be51-7e4ca2b595e0                                   NaN
# 07c9b103-81e3-425e-bdb0-3ad0b968eff2                                   NaN
# 0a944835-ed0e-4778-b5b1-1e932970c57d                                   NaN
# 0c63e045-ccc6-453c-9aa4-23b33e6f263d                                   NaN
# 0eb4e4eb-710d-4335-b214-9be9e8e37383                                   NaN
#
# album_id                              00023c63-5cf0-496b-9fed-aedd51e258bd  \
# critic_id
# 06193874-b01f-4bde-be51-7e4ca2b595e0                                   NaN
# 07c9b103-81e3-425e-bdb0-3ad0b968eff2                                   NaN
# 0a944835-ed0e-4778-b5b1-1e932970c57d                                   NaN
# 0c63e045-ccc6-453c-9aa4-23b33e6f263d                                   NaN
# 0eb4e4eb-710d-4335-b214-9be9e8e37383                                   NaN
#
# album_id                              0002e56a-0c28-4e7d-a417-70ba6069674b  \
# critic_id
# 06193874-b01f-4bde-be51-7e4ca2b595e0                                   NaN
# 07c9b103-81e3-425e-bdb0-3ad0b968eff2                                   NaN
# 0a944835-ed0e-4778-b5b1-1e932970c57d                                   NaN
# 0c63e045-ccc6-453c-9aa4-23b33e6f263d                                   NaN
# 0eb4e4eb-710d-4335-b214-9be9e8e37383                                   NaN
#
# album_id                              000cbff7-17f1-4dd8-9cd9-5eb1157fbb95  \
# critic_id
# 06193874-b01f-4bde-be51-7e4ca2b595e0                                   NaN
# 07c9b103-81e3-425e-bdb0-3ad0b968eff2                                   NaN
# 0a944835-ed0e-4778-b5b1-1e932970c57d                                   NaN
# 0c63e045-ccc6-453c-9aa4-23b33e6f263d                                   NaN
# 0eb4e4eb-710d-4335-b214-9be9e8e37383                                   NaN
#
# album_id                              0013b996-5b63-4dd3-aeea-d6a05b9f27ed  \
# critic_id
# 06193874-b01f-4bde-be51-7e4ca2b595e0                                   NaN
# 07c9b103-81e3-425e-bdb0-3ad0b968eff2                                   NaN
# 0a944835-ed0e-4778-b5b1-1e932970c57d                                   NaN
# 0c63e045-ccc6-453c-9aa4-23b33e6f263d                                   NaN
# 0eb4e4eb-710d-4335-b214-9be9e8e37383                                   NaN
#
# album_id                              0016bb78-ca68-4364-bc22-34047f61ea04  \
# critic_id
# 06193874-b01f-4bde-be51-7e4ca2b595e0                                   NaN
# 07c9b103-81e3-425e-bdb0-3ad0b968eff2                                   NaN
# 0a944835-ed0e-4778-b5b1-1e932970c57d                                   NaN
# 0c63e045-ccc6-453c-9aa4-23b33e6f263d                                   NaN
# 0eb4e4eb-710d-4335-b214-9be9e8e37383                                   NaN
#
# album_id                              001f620a-190a-405f-bc11-b1d8d95007eb  \
# critic_id
# 06193874-b01f-4bde-be51-7e4ca2b595e0                                   NaN
# 07c9b103-81e3-425e-bdb0-3ad0b968eff2                                   NaN
# 0a944835-ed0e-4778-b5b1-1e932970c57d                                   NaN
# 0c63e045-ccc6-453c-9aa4-23b33e6f263d                                   NaN
# 0eb4e4eb-710d-4335-b214-9be9e8e37383                                   NaN
#
# album_id                              00216190-8202-46f3-9952-45b061802075  \
# critic_id
# 06193874-b01f-4bde-be51-7e4ca2b595e0                                   NaN
# 07c9b103-81e3-425e-bdb0-3ad0b968eff2                                   NaN
# 0a944835-ed0e-4778-b5b1-1e932970c57d                                   NaN
# 0c63e045-ccc6-453c-9aa4-23b33e6f263d                                   NaN
# 0eb4e4eb-710d-4335-b214-9be9e8e37383                                   NaN
#
# album_id                              0023d132-670c-4ac5-8b83-d49b373ec595  \
# critic_id
# 06193874-b01f-4bde-be51-7e4ca2b595e0                                   NaN
# 07c9b103-81e3-425e-bdb0-3ad0b968eff2                                   NaN
# 0a944835-ed0e-4778-b5b1-1e932970c57d                                   NaN
# 0c63e045-ccc6-453c-9aa4-23b33e6f263d                                   NaN
# 0eb4e4eb-710d-4335-b214-9be9e8e37383                                   NaN
#
# album_id                              0023d215-eae3-4d0e-855c-31562215be26  \
# critic_id
# 06193874-b01f-4bde-be51-7e4ca2b595e0                                  80.0
# 07c9b103-81e3-425e-bdb0-3ad0b968eff2                                   NaN
# 0a944835-ed0e-4778-b5b1-1e932970c57d                                   NaN
# 0c63e045-ccc6-453c-9aa4-23b33e6f263d                                   NaN
# 0eb4e4eb-710d-4335-b214-9be9e8e37383                                   NaN
#
# album_id                                              ...                   \
# critic_id                                             ...
# 06193874-b01f-4bde-be51-7e4ca2b595e0                  ...
# 07c9b103-81e3-425e-bdb0-3ad0b968eff2                  ...
# 0a944835-ed0e-4778-b5b1-1e932970c57d                  ...
# 0c63e045-ccc6-453c-9aa4-23b33e6f263d                  ...
# 0eb4e4eb-710d-4335-b214-9be9e8e37383                  ...
#
# album_id                              ffcb36a0-3597-4f41-b5e4-2f754b0d32fd  \
# critic_id
# 06193874-b01f-4bde-be51-7e4ca2b595e0                                   NaN
# 07c9b103-81e3-425e-bdb0-3ad0b968eff2                                   NaN
# 0a944835-ed0e-4778-b5b1-1e932970c57d                                   NaN
# 0c63e045-ccc6-453c-9aa4-23b33e6f263d                                   NaN
# 0eb4e4eb-710d-4335-b214-9be9e8e37383                                   NaN
#
# album_id                              ffd2610f-6e51-418c-9a55-c9df19943795  \
# critic_id
# 06193874-b01f-4bde-be51-7e4ca2b595e0                                   NaN
# 07c9b103-81e3-425e-bdb0-3ad0b968eff2                                   NaN
# 0a944835-ed0e-4778-b5b1-1e932970c57d                                   NaN
# 0c63e045-ccc6-453c-9aa4-23b33e6f263d                                   NaN
# 0eb4e4eb-710d-4335-b214-9be9e8e37383                                   NaN
#
# album_id                              ffdbe0bc-5319-468a-a971-db16b0ea21d3  \
# critic_id
# 06193874-b01f-4bde-be51-7e4ca2b595e0                                   NaN
# 07c9b103-81e3-425e-bdb0-3ad0b968eff2                                   NaN
# 0a944835-ed0e-4778-b5b1-1e932970c57d                                   NaN
# 0c63e045-ccc6-453c-9aa4-23b33e6f263d                                   NaN
# 0eb4e4eb-710d-4335-b214-9be9e8e37383                                   NaN
#
# album_id                              ffe6671b-46d2-4d12-aff3-fa88323caef3  \
# critic_id
# 06193874-b01f-4bde-be51-7e4ca2b595e0                                   NaN
# 07c9b103-81e3-425e-bdb0-3ad0b968eff2                                   NaN
# 0a944835-ed0e-4778-b5b1-1e932970c57d                                   NaN
# 0c63e045-ccc6-453c-9aa4-23b33e6f263d                                   NaN
# 0eb4e4eb-710d-4335-b214-9be9e8e37383                                   NaN
#
# album_id                              ffed69c0-a428-4fb3-bc17-3850dcb70e60  \
# critic_id
# 06193874-b01f-4bde-be51-7e4ca2b595e0                                  90.0
# 07c9b103-81e3-425e-bdb0-3ad0b968eff2                                   NaN
# 0a944835-ed0e-4778-b5b1-1e932970c57d                                  68.0
# 0c63e045-ccc6-453c-9aa4-23b33e6f263d                                   NaN
# 0eb4e4eb-710d-4335-b214-9be9e8e37383                                   NaN
#
# album_id                              ffee18ab-7a95-4305-984c-4a24ee9497d7  \
# critic_id
# 06193874-b01f-4bde-be51-7e4ca2b595e0                                   NaN
# 07c9b103-81e3-425e-bdb0-3ad0b968eff2                                   NaN
# 0a944835-ed0e-4778-b5b1-1e932970c57d                                   NaN
# 0c63e045-ccc6-453c-9aa4-23b33e6f263d                                   NaN
# 0eb4e4eb-710d-4335-b214-9be9e8e37383                                   NaN
#
# album_id                              fff1d03a-ff43-48de-993b-e02afb2355cf  \
# critic_id
# 06193874-b01f-4bde-be51-7e4ca2b595e0                                   NaN
# 07c9b103-81e3-425e-bdb0-3ad0b968eff2                                   NaN
# 0a944835-ed0e-4778-b5b1-1e932970c57d                                   NaN
# 0c63e045-ccc6-453c-9aa4-23b33e6f263d                                   NaN
# 0eb4e4eb-710d-4335-b214-9be9e8e37383                                   NaN
#
# album_id                              fff91846-ec09-4cf2-9446-a58f032d2e44  \
# critic_id
# 06193874-b01f-4bde-be51-7e4ca2b595e0                                   NaN
# 07c9b103-81e3-425e-bdb0-3ad0b968eff2                                   NaN
# 0a944835-ed0e-4778-b5b1-1e932970c57d                                   NaN
# 0c63e045-ccc6-453c-9aa4-23b33e6f263d                                   NaN
# 0eb4e4eb-710d-4335-b214-9be9e8e37383                                  80.0
#
# album_id                              fffbb171-a1df-418e-83d0-0ecd89a0828e  \
# critic_id
# 06193874-b01f-4bde-be51-7e4ca2b595e0                                   NaN
# 07c9b103-81e3-425e-bdb0-3ad0b968eff2                                   NaN
# 0a944835-ed0e-4778-b5b1-1e932970c57d                                   NaN
# 0c63e045-ccc6-453c-9aa4-23b33e6f263d                                   NaN
# 0eb4e4eb-710d-4335-b214-9be9e8e37383                                   NaN
#
# album_id                              fffd8d2b-7f94-4d60-a043-ad91f06c68b9
# critic_id
# 06193874-b01f-4bde-be51-7e4ca2b595e0                                  80.0
# 07c9b103-81e3-425e-bdb0-3ad0b968eff2                                   NaN
# 0a944835-ed0e-4778-b5b1-1e932970c57d                                   NaN
# 0c63e045-ccc6-453c-9aa4-23b33e6f263d                                   NaN
# 0eb4e4eb-710d-4335-b214-9be9e8e37383                                   NaN
#
# [5 rows x 15855 columns]

# %%
album_name = input("Enter Your Album: ")
# Out:
# Enter Your Album: Funeral

# %%
album_name
# Out:
# 'Funeral'

# %%
pivot_album_id = albums[albums['name']==album_name].id
pivot_album_id = pivot_album_id.max()
#TODO: get album id as string, not object, so it can be passed to next cell programmatically!

# %%
album_ratings = crosstab[pivot_album_id]
#albums[albums['id']==pivot_album_id]
#album_ratings[album_ratings>=0]

# %%
similar_to_album = crosstab.corrwith(album_ratings)
# Out:
# /Users/michael/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:3159: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# /Users/michael/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:3093: RuntimeWarning: divide by zero encountered in double_scalars
#   c *= 1. / np.float64(fact)

# %%
corr_album = pd.DataFrame(similar_to_album, columns=['PearsonR'])
corr_album.dropna(inplace=True)

# %%
#TODO: Sort by PearsonR, set minimum number of ratings (join)
corr_summary = corr_album.join(rating_totals)
corr_summary.head()
# Out:
#                                       PearsonR  rating_count  album_rating  \
# album_id
# 000170c8-cc89-418f-85d6-99b2cddbfe2a -0.007065             6          73.0
# 00023c63-5cf0-496b-9fed-aedd51e258bd -0.384349            11          75.0
# 000cbff7-17f1-4dd8-9cd9-5eb1157fbb95 -0.431797            20          61.0
# 0016bb78-ca68-4364-bc22-34047f61ea04  0.894427             6          88.0
# 001f620a-190a-405f-bc11-b1d8d95007eb  0.189476            10          76.0
#
#                                                                  mc_rating  \
# album_id
# 000170c8-cc89-418f-85d6-99b2cddbfe2a  Ten Songs from Live at Carnegie Hall
# 00023c63-5cf0-496b-9fed-aedd51e258bd                          New Favorite
# 000cbff7-17f1-4dd8-9cd9-5eb1157fbb95                        T.I. Vs T.I.P.
# 0016bb78-ca68-4364-bc22-34047f61ea04                             Brutalism
# 001f620a-190a-405f-bc11-b1d8d95007eb                         Forever Today
#
#                                                              artist
# album_id
# 000170c8-cc89-418f-85d6-99b2cddbfe2a                     Ryan Adams
# 00023c63-5cf0-496b-9fed-aedd51e258bd  Alison Krauss & Union Station
# 000cbff7-17f1-4dd8-9cd9-5eb1157fbb95                           T.I.
# 0016bb78-ca68-4364-bc22-34047f61ea04                          Idles
# 001f620a-190a-405f-bc11-b1d8d95007eb             I'm from Barcelona

# %%
corr_summary[corr_summary['rating_count']>=25].sort_values('PearsonR', ascending=False).head(10)
# Out:
#                                       PearsonR  rating_count  album_rating  \
# album_id
# b5438c07-02b5-41c7-a78d-596b5ba8cc5e  1.000000            33     86.969697
# b663a6be-a1a8-4694-8904-3a57cd34d2ff  0.707450            28     75.821429
# 0784e981-72ab-4d05-8ce8-8944f203d10d  0.686086            28     77.535714
# 3479070b-80f6-4c75-8bdb-1a38ab3918a7  0.669224            33     72.424242
# eceab1b5-894d-4a9a-abcf-3e77db0ba05d  0.668704            27     70.444444
# 9a3bf4a3-dd2a-4be3-9dd5-47aed059d2ed  0.668694            25     82.640000
# 3b8376ed-0d3a-4ce5-821c-16c980b7f985  0.645986            33     75.727273
# 4bd1b744-eb07-42af-83ab-628ab921af05  0.642853            26     72.884615
# 0f6c93cb-7636-4146-b3ee-ceffefb3752e  0.634001            34     84.088235
# 3a25198e-bb5c-423b-8111-62f5859279b7  0.630752            26     73.423077
#
#                                                      album_name  \
# album_id
# b5438c07-02b5-41c7-a78d-596b5ba8cc5e                    Funeral
# b663a6be-a1a8-4694-8904-3a57cd34d2ff               Desire Lines
# 0784e981-72ab-4d05-8ce8-8944f203d10d               I'm New Here
# 3479070b-80f6-4c75-8bdb-1a38ab3918a7                      (III)
# eceab1b5-894d-4a9a-abcf-3e77db0ba05d                  With Love
# 9a3bf4a3-dd2a-4be3-9dd5-47aed059d2ed             Run the Jewels
# 3b8376ed-0d3a-4ce5-821c-16c980b7f985                      Atlas
# 4bd1b744-eb07-42af-83ab-628ab921af05                    Eagulls
# 0f6c93cb-7636-4146-b3ee-ceffefb3752e      I Love You, Honeybear
# 3a25198e-bb5c-423b-8111-62f5859279b7  The  Dreamer/The Believer
#
#                                                  artist
# album_id
# b5438c07-02b5-41c7-a78d-596b5ba8cc5e        Arcade Fire
# b663a6be-a1a8-4694-8904-3a57cd34d2ff     Camera Obscura
# 0784e981-72ab-4d05-8ce8-8944f203d10d    Gil Scott-Heron
# 3479070b-80f6-4c75-8bdb-1a38ab3918a7    Crystal Castles
# eceab1b5-894d-4a9a-abcf-3e77db0ba05d              Zomby
# 9a3bf4a3-dd2a-4be3-9dd5-47aed059d2ed               El-P
# 3b8376ed-0d3a-4ce5-821c-16c980b7f985        Real Estate
# 4bd1b744-eb07-42af-83ab-628ab921af05            Eagulls
# 0f6c93cb-7636-4146-b3ee-ceffefb3752e  Father John Misty
# 3a25198e-bb5c-423b-8111-62f5859279b7             Common

# %%
albums[albums['id']=='0784e981-72ab-4d05-8ce8-8944f203d10d']
# Out:
#                                         id          name           artist  \
# 5075  0784e981-72ab-4d05-8ce8-8944f203d10d  I'm New Here  Gil Scott-Heron
#
#                  genres                                link  \
# 5075  [Rap, R&B, Blues]  /music/im-new-here/gil-scott-heron
#
#                                                img_link  mc_rating  usr_rating
# 5075  http://static.metacritic.com/images/products/m...       78.0         8.8
