# %%
import requests
from bs4 import BeautifulSoup
from warnings import warn

# %%
import time

#explicitly calling the urls since there are only two pages, otherwise we might want to iterate
urls = ['http://www.metacritic.com/browse/albums/publication/score?num_items=100&page=0','http://www.metacritic.com/browse/albums/publication/score?num_items=100&page=1']
publications_list = []

start = time.time()
for u in urls:
    page = requests.get(u, headers={'User-Agent': 'Mozilla/5.0'})
    if page.status_code != 200:
        warn("Status code for " + u + "was " + u.status_code())
    else:
        print("processing " + u + "...")
    soup = BeautifulSoup(page.text, 'html.parser')
    publications = soup.findAll('div',attrs={'class':'product_wrap'})
    publications_list.extend(publications)

end = time.time()
print("execution time: " + str(end - start) + "s")
# Out:
# processing http://www.metacritic.com/browse/albums/publication/score?num_items=100&page=0...
# processing http://www.metacritic.com/browse/albums/publication/score?num_items=100&page=1...
# execution time: 3.680203914642334s

# %%
names = []
review_counts = []
review_averages = []

def get_num(x):
    return int(''.join(ele for ele in x if ele.isdigit()))

start = time.time()
for p in publications_list:
    #finding the title div element containing publication name and total # reviews
    title = p.find('div',attrs={'class':'title'})
    
    #name
    publication_name = title.find("a").get_text()
    names.append(publication_name)
    
    #total album review count
    publication_album_count = title.find('span',attrs={'class':'count'}).get_text()
    publication_album_count = get_num(publication_album_count)
    review_counts.append(publication_album_count)
    
    #average album review score    
    publication_average_score = p.select("span[class*=average_score]")[0].get_text()
    review_averages.append(int(publication_average_score))

end = time.time()
print("execution time: " + str(end - start) + "s")
# Out:
# execution time: 0.04835081100463867s

# %%
import pandas as pd

# %%
# creating our macro-level data frame
macro_df = pd.DataFrame({
    'publication': names,
    'total reviews': review_counts,
    'average score': review_averages
})

print(macro_df.info())
macro_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129 entries, 0 to 128
# Data columns (total 3 columns):
# average score    129 non-null int64
# publication      129 non-null object
# total reviews    129 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 3.1+ KB
# None
#      average score                                 publication  total reviews
# 0               91                  Expert Witness (MSN Music)            232
# 1               86       MSN Consumer Guide (Robert Christgau)            178
# 2               86      Alternative Press (Record Of The Week)              5
# 3               85                                  Okayplayer            148
# 4               83                           Ink Blot Magazine             85
# 5               82              Village Voice (Consumer Guide)            223
# 6               81               Absolute Punk (Staff reviews)            811
# 7               80                              Country Weekly            157
# 8               79                           Metal Hammer (UK)             25
# 9               78                                      Mixmag            428
# 10              78                                      Planet             34
# 11              78                        Entertainment Weekly           3377
# 12              78                                   Resonance             33
# 13              77                                 Lost At Sea            628
# 14              77                                     Outburn             24
# 15              77                       Delusions of Adequacy           1376
# 16              76                               Billboard.com            825
# 17              76                                  Amazon.com            468
# 18              76                          The Telegraph (UK)            676
# 19              76                        The Line of Best Fit           2247
# 20              76                                       XLR8r            366
# 21              75                                      Filter           1801
# 22              75                                  Rock Sound            495
# 23              75                              Paste Magazine           2972
# 24              75                                    DJ Booth            155
# 25              75                        Punknews.org (Staff)            369
# 26              75                                   E! Online            787
# 27              75                                    Splendid            793
# 28              75  Beats Per Minute (formerly One Thirty BPM)            843
# 29              74                                 The Quietus           1420
# ..             ...                                         ...            ...
# 99              69                                   Pitchfork           8768
# 100             69                             CultureDose.net             68
# 101             69                                   Dot Music           1511
# 102             69                   New Musical Express (NME)           4423
# 103             69                            Austin Chronicle           1822
# 104             69                                The Guardian           4453
# 105             69                             Stylus Magazine           1453
# 106             68                                      Ink 19             68
# 107             68                                     HOB.com            101
# 108             68                              Tiny Mix Tapes           2728
# 109             68                                  PopMatters           9242
# 110             68                                        Vibe            290
# 111             68                                     Complex             49
# 112             68                               Village Voice            764
# 113             67                        The Independent (UK)           1439
# 114             67                        Consequence of Sound           3434
# 115             67                             Shredding Paper             13
# 116             67                                   Hot Press            497
# 117             66                             Under The Radar           4482
# 118             66             New York Daily News (Jim Faber)            136
# 119             66                                  Q Magazine           7383
# 120             66                           The Observer (UK)           1645
# 121             66                                NOW Magazine           2719
# 122             66                               Rolling Stone           4802
# 123             65                                     Blender           1854
# 124             65                                  Revolution             10
# 125             65                 New York Magazine (Vulture)            158
# 126             64                              Slant Magazine           2514
# 127             63                                    Drawer B            121
# 128             60                                      Select             41
#
# [129 rows x 3 columns]

# %%
import plotly
import plotly.graph_objs as go

plotly.offline.init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
import numpy as np
print("Average Album Review")
np.average(macro_df['average score'], weights=macro_df['total reviews'])

print("Summary Statistics: Average Publication Scores")
print(macro_df['average score'].describe())
print("median score: " + str(macro_df['average score'].median()))

print("Summary Statistics: Average Publication Review Count")
print(macro_df['total reviews'].describe())

print(str(macro_df['total reviews'].sum()))
# Out:
# Average Album Review
# Summary Statistics: Average Publication Scores
# count    129.000000
# mean      72.348837
# std        4.642957
# min       60.000000
# 25%       70.000000
# 50%       72.000000
# 75%       74.000000
# max       91.000000
# Name: average score, dtype: float64
# median score: 72.0
# Summary Statistics: Average Publication Review Count
# count      129.000000
# mean      1460.534884
# std       2066.077337
# min          3.000000
# 25%        158.000000
# 50%        712.000000
# 75%       1822.000000
# max      12779.000000
# Name: total reviews, dtype: float64
# 188409

# %%
data1 = go.Histogram(x = macro_df['average score'],)
layout1 = go.Layout(
    title= 'Average Scores Across Publications',
    hovermode= 'closest',
    xaxis = dict(
        title= 'Average Score',
    ),
    yaxis = dict(
        title = 'Number of Publications'
    )
)

fig1 = dict(data=[data1], layout=layout1)
iplot(fig1, filename='basic histogram')

data2 = go.Histogram(x=macro_df['total reviews'])
layout2 = go.Layout(
    title= 'Average Scores Across Publications',
    hovermode= 'closest',
    xaxis = dict(
        title= 'Number of Reviews',
    ),
    yaxis = dict(
        title = 'Number of Publications'
    )
)

fig2_1 = dict(data=[data2], layout=layout2)
iplot(fig2, filename='basic histogram')
# Out:
# <div id="3b839a60-6cb1-4d92-9be4-005c8b50a248" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("3b839a60-6cb1-4d92-9be4-005c8b50a248", [{"type": "histogram", "x": [91, 86, 86, 85, 83, 82, 81, 80, 79, 78, 78, 78, 78, 77, 77, 77, 76, 76, 76, 76, 76, 75, 75, 75, 75, 75, 75, 75, 75, 74, 74, 74, 74, 74, 74, 74, 74, 74, 74, 74, 74, 74, 74, 74, 74, 74, 73, 73, 73, 73, 73, 73, 73, 73, 73, 73, 73, 73, 73, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 71, 71, 71, 71, 71, 71, 71, 71, 71, 71, 71, 70, 70, 70, 70, 70, 70, 70, 70, 70, 70, 70, 70, 69, 69, 69, 69, 69, 69, 69, 68, 68, 68, 68, 68, 68, 68, 67, 67, 67, 67, 66, 66, 66, 66, 66, 66, 65, 65, 65, 64, 63, 60]}], {"title": "Average Scores Across Publications", "hovermode": "closest", "xaxis": {"title": "Average Score"}, "yaxis": {"title": "Number of Publications"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>
# <div id="61dbfe1e-fab3-4035-9e07-795abb966315" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("61dbfe1e-fab3-4035-9e07-795abb966315", [{"type": "histogram", "x": [232, 178, 5, 148, 85, 223, 811, 157, 25, 428, 34, 3377, 33, 628, 24, 1376, 825, 468, 676, 2247, 366, 1801, 495, 2972, 155, 369, 787, 793, 843, 1420, 1094, 2965, 728, 88, 4242, 1091, 1083, 1831, 1720, 61, 140, 12779, 150, 491, 342, 726, 59, 581, 3071, 703, 712, 1126, 75, 1330, 2294, 354, 232, 235, 12, 4367, 110, 474, 3, 1471, 542, 1554, 826, 1122, 410, 494, 2035, 2021, 1598, 403, 513, 52, 2439, 70, 1772, 6821, 370, 789, 4541, 517, 421, 287, 448, 62, 1773, 7977, 1624, 49, 99, 1832, 169, 3977, 2132, 823, 2138, 8768, 68, 1511, 4423, 1822, 4453, 1453, 68, 101, 2728, 9242, 290, 49, 764, 1439, 3434, 13, 497, 4482, 136, 7383, 1645, 2719, 4802, 1854, 10, 158, 2514, 121, 41]}], {"title": "Average Scores Across Publications", "hovermode": "closest", "xaxis": {"title": "Number of Reviews"}, "yaxis": {"title": "Number of Publications"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
N = 500

data3 = go.Scatter(
    x = macro_df['total reviews'],
    y = macro_df['average score'],
    text = macro_df['publication'],
    name = 'Above',
    mode = 'markers',
    marker = dict(
        size = 5,
        color = 'rgba(152, 0, 0, .8)',
        line = dict(
            width = 2,
            color = 'rgb(0, 0, 0)'
        )
    )
)

layout3= go.Layout(
    title= 'Average Rating vs. Number of Reviews By Publication',
    hovermode= 'closest',
    xaxis= dict(
        title= 'Number of Reviews',
        #type = 'log',
        zeroline= False,
        gridwidth= 2,
    ),
    yaxis=dict(
        title= 'Average Rating (100 max)',
        gridwidth= 2,
    ),
    showlegend= False
)

z = np.polyfit(macro_df['total reviews'],macro_df['average score'],1)
p = np.poly1d(z) 

print("Linear Regression: " + str(p))

fig3 = dict(data=[data3], layout=layout3)
iplot(fig3, filename='styled-scatter')
# Out:
# Linear Regression:
# -0.000494 x + 73.07
# <div id="a3860d13-0e96-4d79-974a-7b997e533ea6" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("a3860d13-0e96-4d79-974a-7b997e533ea6", [{"type": "scatter", "x": [232, 178, 5, 148, 85, 223, 811, 157, 25, 428, 34, 3377, 33, 628, 24, 1376, 825, 468, 676, 2247, 366, 1801, 495, 2972, 155, 369, 787, 793, 843, 1420, 1094, 2965, 728, 88, 4242, 1091, 1083, 1831, 1720, 61, 140, 12779, 150, 491, 342, 726, 59, 581, 3071, 703, 712, 1126, 75, 1330, 2294, 354, 232, 235, 12, 4367, 110, 474, 3, 1471, 542, 1554, 826, 1122, 410, 494, 2035, 2021, 1598, 403, 513, 52, 2439, 70, 1772, 6821, 370, 789, 4541, 517, 421, 287, 448, 62, 1773, 7977, 1624, 49, 99, 1832, 169, 3977, 2132, 823, 2138, 8768, 68, 1511, 4423, 1822, 4453, 1453, 68, 101, 2728, 9242, 290, 49, 764, 1439, 3434, 13, 497, 4482, 136, 7383, 1645, 2719, 4802, 1854, 10, 158, 2514, 121, 41], "y": [91, 86, 86, 85, 83, 82, 81, 80, 79, 78, 78, 78, 78, 77, 77, 77, 76, 76, 76, 76, 76, 75, 75, 75, 75, 75, 75, 75, 75, 74, 74, 74, 74, 74, 74, 74, 74, 74, 74, 74, 74, 74, 74, 74, 74, 74, 73, 73, 73, 73, 73, 73, 73, 73, 73, 73, 73, 73, 73, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 71, 71, 71, 71, 71, 71, 71, 71, 71, 71, 71, 70, 70, 70, 70, 70, 70, 70, 70, 70, 70, 70, 70, 69, 69, 69, 69, 69, 69, 69, 68, 68, 68, 68, 68, 68, 68, 67, 67, 67, 67, 66, 66, 66, 66, 66, 66, 65, 65, 65, 64, 63, 60], "text": ["Expert Witness (MSN Music)", "MSN Consumer Guide (Robert Christgau)", "Alternative Press (Record Of The Week)", "Okayplayer", "Ink Blot Magazine", "Village Voice (Consumer Guide)", "Absolute Punk (Staff reviews)", "Country Weekly", "Metal Hammer (UK)", "Mixmag", "Planet", "Entertainment Weekly", "Resonance", "Lost At Sea", "Outburn", "Delusions of Adequacy", "Billboard.com", "Amazon.com", "The Telegraph (UK)", "The Line of Best Fit", "XLR8r", "Filter", "Rock Sound", "Paste Magazine", "DJ Booth", "Punknews.org (Staff)", "E! Online", "Splendid", "Beats Per Minute (formerly One Thirty BPM)", "The Quietus", "The 405", "Exclaim", "CMJ", "Logo", "The A.V. Club", "The Boston Phoenix", "Kerrang!", "BBC Music", "Billboard", "The Source", "Nude As The News", "AllMusic", "BBC collective", "ShakingThrough.net", "XXL", "Resident Advisor", "Checkout.com", "Observer Music Monthly", "Alternative Press", "RapReviews.com", "Pretty Much Amazing", "Urb", "MTV.com", "Blurt Magazine", "Magnet", "Launch.com", "Wall of Sound", "Revolver", "Puncture", "musicOMH.com", "Mixer", "Neumu.net", "Epilogue Music", "Los Angeles Times", "HipHopDX", "Record Collector", "Classic Rock Magazine", "American Songwriter", "Almost Cool", "Chicago Tribune", "Boston Globe", "Clash Music", "The Wire", "Junkmedia", "The Skinny", "Salon.com", "Dusted Magazine", "L.A. Weekly", "cokemachineglow", "Mojo", "The Fly (UK)", "The Independent on Sunday (UK)", "Drowned In Sound", "Hartford Courant", "CDNow", "Sonicnet", "Fact Magazine (UK)", "Flak Magazine", "DIY Magazine", "Uncut", "Sputnikmusic", "Armchair DJ", "Spin Cycle", "The New York Times", "Trouser Press", "Spin", "Prefix Magazine", "Playlouder", "No Ripcord", "Pitchfork", "CultureDose.net", "Dot Music", "New Musical Express (NME)", "Austin Chronicle", "The Guardian", "Stylus Magazine", "Ink 19", "HOB.com", "Tiny Mix Tapes", "PopMatters", "Vibe", "Complex", "Village Voice", "The Independent (UK)", "Consequence of Sound", "Shredding Paper", "Hot Press", "Under The Radar", "New York Daily News (Jim Faber)", "Q Magazine", "The Observer (UK)", "NOW Magazine", "Rolling Stone", "Blender", "Revolution", "New York Magazine (Vulture)", "Slant Magazine", "Drawer B", "Select"], "name": "Above", "mode": "markers", "marker": {"size": 5, "color": "rgba(152, 0, 0, .8)", "line": {"width": 2, "color": "rgb(0, 0, 0)"}}}], {"title": "Average Rating vs. Number of Reviews By Publication", "hovermode": "closest", "xax ...

# %%
macro_df['paginations'] = macro_df['total reviews']
macro_df.loc[:,'paginations'] *= (0.01)
macro_df['paginations'] = np.ceil(macro_df['paginations'])
macro_df
# Out:
#      average score                                 publication  total reviews  \
# 0               91                  Expert Witness (MSN Music)            232
# 1               86       MSN Consumer Guide (Robert Christgau)            178
# 2               86      Alternative Press (Record Of The Week)              5
# 3               85                                  Okayplayer            148
# 4               83                           Ink Blot Magazine             85
# 5               82              Village Voice (Consumer Guide)            223
# 6               81               Absolute Punk (Staff reviews)            811
# 7               80                              Country Weekly            157
# 8               79                           Metal Hammer (UK)             25
# 9               78                                      Mixmag            428
# 10              78                                      Planet             34
# 11              78                        Entertainment Weekly           3377
# 12              78                                   Resonance             33
# 13              77                                 Lost At Sea            628
# 14              77                                     Outburn             24
# 15              77                       Delusions of Adequacy           1376
# 16              76                               Billboard.com            825
# 17              76                                  Amazon.com            468
# 18              76                          The Telegraph (UK)            676
# 19              76                        The Line of Best Fit           2247
# 20              76                                       XLR8r            366
# 21              75                                      Filter           1801
# 22              75                                  Rock Sound            495
# 23              75                              Paste Magazine           2972
# 24              75                                    DJ Booth            155
# 25              75                        Punknews.org (Staff)            369
# 26              75                                   E! Online            787
# 27              75                                    Splendid            793
# 28              75  Beats Per Minute (formerly One Thirty BPM)            843
# 29              74                                 The Quietus           1420
# ..             ...                                         ...            ...
# 99              69                                   Pitchfork           8768
# 100             69                             CultureDose.net             68
# 101             69                                   Dot Music           1511
# 102             69                   New Musical Express (NME)           4423
# 103             69                            Austin Chronicle           1822
# 104             69                                The Guardian           4453
# 105             69                             Stylus Magazine           1453
# 106             68                                      Ink 19             68
# 107             68                                     HOB.com            101
# 108             68                              Tiny Mix Tapes           2728
# 109             68                                  PopMatters           9242
# 110             68                                        Vibe            290
# 111             68                                     Complex             49
# 112             68                               Village Voice            764
# 113             67                        The Independent (UK)           1439
# 114             67                        Consequence of Sound           3434
# 115             67                             Shredding Paper             13
# 116             67                                   Hot Press            497
# 117             66                             Under The Radar           4482
# 118             66             New York Daily News (Jim Faber)            136
# 119             66                                  Q Magazine           7383
# 120             66                           The Observer (UK)           1645
# 121             66                                NOW Magazine           2719
# 122             66                               Rolling Stone           4802
# 123             65                                     Blender           1854
# 124             65                                  Revolution             10
# 125             65                 New York Magazine (Vulture)            158
# 126             64                              Slant Magazine           2514
# 127             63                                    Drawer B            121
# 128             60                                      Select             41
#
#      paginations
# 0            3.0
# 1            2.0
# 2            1.0
# 3            2.0
# 4            1.0
# 5            3.0
# 6            9.0
# 7            2.0
# 8            1.0
# 9            5.0
# 10           1.0
# 11          34.0
# 12           1.0
# 13           7.0
# 14           1.0
# 15          14.0
# 16           9.0
# 17           5.0
# 18           7.0
# 19          23.0
# 20           4.0
# 21          19.0
# 22           5.0
# 23          30.0
# 24           2.0
# 25           4.0
# 26           8.0
# 27           8.0
# 28           9.0
# 29          15.0
# ..           ...
# 99          88.0
# 100          1.0
# 101         16.0
# 102         45.0
# 103         19.0
# 104         45.0
# 105         15.0
# 106          1.0
# 107          2.0
# 108         28.0
# 109         93.0
# 110          3.0
# 111          1.0
# 112          8.0
# 113         15.0
# 114         35.0
# 115          1.0
# 116          5.0
# 117         45.0
# 118          2.0
# 119         74.0
# 120         17.0
# 121         28.0
# 122         49.0
# 123         19.0
# 124          1.0
# 125          2.0
# 126         26.0
# 127          2.0
# 128          1.0
#
# [129 rows x 4 columns]

# %%
print("Total links to follow via publication pages:")
macro_df['paginations'].sum()
# Out:
# Total links to follow via publication pages:
# 1951.0
